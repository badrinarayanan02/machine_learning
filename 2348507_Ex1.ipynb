# %% [markdown]
# <a href="https://colab.research.google.com/github/badrinarayanan02/machine_learning/blob/main/2348507_Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/data - data.csv')
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 0:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 0:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 0:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 0:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 0:00  5.500000e+05         4       2.50         1940
# ...               ...           ...       ...        ...          ...
# 4595  09-07-2014 0:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 0:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 0:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 0:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 0:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
data.shape
# Out:
# (4600, 18)

# %%
data.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %% [markdown]
# # **Exploratory data analysis**

# %% [markdown]
# Visualizing the distribution of price using boxplot

# %%
plt.boxplot(data['price'])

plt.xlabel('Price')
plt.ylabel('Value')
plt.title('Distribution of Price')

plt.show()

# %% [markdown]
# Visualizing the relationship between bedroom and price using scatter plot

# %%
plt.scatter(data['bedrooms'], data['price'])

plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.title('Relationship between Bedrooms and Price')

plt.show()

# %% [markdown]
# Displaying the distribution of sqft living by city using boxplot

# %%
plt.figure(figsize=(12, 10))

sns.boxplot(x='city', y='sqft_living', data=data)

plt.xticks(rotation=45)

plt.xlabel('City')
plt.ylabel('Sqft Living')
plt.title('Distribution of Sqft Living by City')

plt.show()

# %% [markdown]
# Distribution of bathroom across different floors

# %%
mean_bathrooms_per_floor = data.groupby('floors')['bathrooms'].mean().reset_index()

sns.barplot(x='floors', y='bathrooms', data=mean_bathrooms_per_floor)

plt.xlabel('Number of Floors')
plt.ylabel('Average Number of Bathrooms')
plt.title('Average Number of Bathrooms across Floors')

plt.show()

# %% [markdown]
# Distribution of year built and year renovated

# %%
year_built_counts = data['yr_built'].value_counts().sort_index()
year_renovated_counts = data['yr_renovated'].value_counts().sort_index()


plt.bar(year_built_counts.index, year_built_counts.values, alpha=0.5, label='Year Built')
plt.bar(year_renovated_counts.index, year_renovated_counts.values, alpha=0.5, label='Year Renovated')

plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Distribution of Year Built and Year Renovated')

plt.legend()

plt.show()

# %% [markdown]
# Applying Bin Means and Bin Boundaries for attributes "Year Built" and "Sqft_Above"

# %%
year_built_bins = [1900, 1920, 1940, 1960, 1980, 2000, 2020]

data['year_built_bin'] = pd.cut(data['yr_built'], bins=year_built_bins, include_lowest=True)

sqft_above_bins = [0, 1000, 1500, 2000, 2500, 3000, float('inf')]

data['sqft_above_bin'] = pd.cut(data['sqft_above'], bins=sqft_above_bins, include_lowest=True, right=False)

mean_sqft_above = data.groupby('year_built_bin')['sqft_above'].mean()

mean_year_built = data.groupby('sqft_above_bin')['yr_built'].mean()

print("Mean Sqft Above for Each Year Built Bin:")
print(mean_sqft_above)

print("\nMean Year Built for Each Sqft Above Bin:")
print(mean_year_built)
# Out:
# Mean Sqft Above for Each Year Built Bin:
# year_built_bin
# (1899.999, 1920.0]    1486.546243
# (1920.0, 1940.0]      1480.241895
# (1940.0, 1960.0]      1349.693946
# (1960.0, 1980.0]      1621.919797
# (1980.0, 2000.0]      2256.456973
# (2000.0, 2020.0]      2295.029016
# Name: sqft_above, dtype: float64
#
# Mean Year Built for Each Sqft Above Bin:
# sqft_above_bin
# [0.0, 1000.0)       1947.293307
# [1000.0, 1500.0)    1963.688378
# [1500.0, 2000.0)    1969.012333
# [2000.0, 2500.0)    1980.457232
# [2500.0, 3000.0)    1990.488208
# [3000.0, inf)       1991.781893
# Name: yr_built, dtype: float64

# %%
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 0:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 0:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 0:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 0:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 0:00  5.500000e+05         4       2.50         1940
# ...               ...           ...       ...        ...          ...
# 4595  09-07-2014 0:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 0:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 0:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 0:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 0:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_living_zscore  \
# ...

# %% [markdown]
# Identifying and normalizing all the attributes that has numerical values, using minmax and zscore normalization.
#
# ---

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns

for column in numerical_columns:
    data[column + '_minmax'] = (data[column] - data[column].min()) / (data[column].max() - data[column].min())

for column in numerical_columns:
    data[column + '_zscore'] = (data[column] - data[column].mean()) / data[column].std()

# %% [markdown]
# Visualizing MinMax Values and Z-Score Values

# %%
processed_columns = [col for col in data.columns if '_minmax' in col or '_zscore' in col]

for column in processed_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data[column], kde=True, color='skyblue')
    plt.title(f'Normalized {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
