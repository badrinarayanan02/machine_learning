# %% [markdown]
# <a href="https://colab.research.google.com/github/badrinarayanan02/machine_learning/blob/main/2348507_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Market Basket Analysis for Groceries dataset using Apriori and FP Growth algorithm

# %% [markdown]
# Loading necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import threading
import warnings
import seaborn as sns
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.frequent_patterns import fpgrowth
warnings.filterwarnings("ignore")

# %% [markdown]
# Reading the Dataset

# %%
grocery_data = pd.read_csv('/content/Groceries_dataset - Groceries_dataset.csv')
grocery_data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %% [markdown]
# Checking the volume of the data

# %%
grocery_data.shape
# Out:
# (38765, 3)

# %% [markdown]
# Making sure if any null values present in the dataset

# %%
grocery_data.isna()
# Out:
#        Member_number   Date  itemDescription
# 0              False  False            False
# 1              False  False            False
# 2              False  False            False
# 3              False  False            False
# 4              False  False            False
# ...              ...    ...              ...
# 38760          False  False            False
# 38761          False  False            False
# 38762          False  False            False
# 38763          False  False            False
# 38764          False  False            False
#
# [38765 rows x 3 columns]

# %% [markdown]
# Storing the data into a list before performing Apriori/ FP Growth algorithm

# %%
transactions = []
for index,row in grocery_data.iterrows():
  transactions.append(row.dropna().tolist())
transactions
# Out:
# [[1808, '21-07-2015', 'tropical fruit'],
#  [2552, '05-01-2015', 'whole milk'],
#  [2300, '19-09-2015', 'pip fruit'],
#  [1187, '12-12-2015', 'other vegetables'],
#  [3037, '01-02-2015', 'whole milk'],
#  [4941, '14-02-2015', 'rolls/buns'],
#  [4501, '08-05-2015', 'other vegetables'],
#  [3803, '23-12-2015', 'pot plants'],
#  [2762, '20-03-2015', 'whole milk'],
#  [4119, '12-02-2015', 'tropical fruit'],
#  [1340, '24-02-2015', 'citrus fruit'],
#  [2193, '14-04-2015', 'beef'],
#  [1997, '21-07-2015', 'frankfurter'],
#  [4546, '03-09-2015', 'chicken'],
#  [4736, '21-07-2015', 'butter'],
#  [1959, '30-03-2015', 'fruit/vegetable juice'],
#  [1974, '03-05-2015', 'packaged fruit/vegetables'],
#  [2421, '02-09-2015', 'chocolate'],
#  [1513, '03-08-2015', 'specialty bar'],
#  [1905, '07-07-2015', 'other vegetables'],
#  [2810, '08-09-2015', 'butter milk'],
#  [2867, '12-11-2015', 'whole milk'],
#  [3962, '18-09-2015', 'tropical fruit'],
#  [1088, '30-11-2015', 'tropical fruit'],
# ...

# %% [markdown]
# Retrieving the values of the itemDescription and visualizing using matplotlib

# %%
value = grocery_data['itemDescription'].value_counts(ascending=False)[:15]
value
# Out:
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# pastry               785
# pip fruit            744
# shopping bags        731
# canned beer          717
# bottled beer         687
# Name: itemDescription, dtype: int64

# %%
plt.figure(figsize=(25,25))
sns.barplot(x=value.index,y=value.values)
plt.show()

# %% [markdown]
# Fixing quantity for each data

# %%
grocery_data['Quantity'] = 1
grocery_data
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
transactions = grocery_data.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               NaN       NaN               NaN
# 1001                               NaN       NaN               NaN
# 1002                               NaN       NaN               NaN
# 1003                               NaN       NaN               NaN
# 1004                               NaN       NaN               NaN
# ...                                ...       ...               ...
# 4996                               NaN       NaN               NaN
# 4997                               NaN       NaN               NaN
# 4998                               NaN       NaN               NaN
# 4999                               NaN       NaN               NaN
# 5000                               NaN       NaN               NaN
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %% [markdown]
#   Filling values

# %%
transactions = transactions.fillna(0)
transactions
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %% [markdown]
# Specifying conditions: If the value of the items less than 0 it will return 0, if it is greater it will return 1

# %%
def encode(value):
  if value <= 0:
    return 0
  elif value >= 0:
    return 1

basket_analysis = transactions.applymap(encode)
basket_analysis
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %% [markdown]
# Implementing threads

# %%
thread_one = threading.Event()
thread_two = threading.Event()

# %% [markdown]
# Assuming [0,0] as ap & fp

# %%
execution_time = [0,0]

# %% [markdown]
# Defining seperate functions for both the algorithms

# %%
def apriori_thread(min_support,min_confidence):
  stime = time.time()
  apriori_results = apriori(basket_analysis,min_support = min_support,use_colnames=True)
  execution_time[0] = time.time()-stime
  thread_one.set()

# %%
def fp_thread(min_support,min_confidence):
  stime = time.time()
  fp_results = fpgrowth(basket_analysis,min_support = min_support,use_colnames=True)
  execution_time[1] = time.time()-stime
  thread_two.set()

# %% [markdown]
# Allowing the user to set the minimum support and confidence levels

# %%
if __name__ == '__main__':
  min_support_ap = float(input("Enter minimum support for apriori algorithm : "))
  min_support_fp = float(input("Enter minimum support for fpgrowth algorithm : "))
  min_confidence_ap = float(input("Enter minimum confidence level for apriori algorithm: "))
  min_confidence_fp = float(input("Enter minimum confidence level for fpgrowth algorithm: "))
# Out:
# Enter minimum support for apriori algorithm : 0.02
# Enter minimum support for fpgrowth algorithm : 0.02
# Enter minimum confidence level for apriori algorithm: 0.4
# Enter minimum confidence level for fpgrowth algorithm: 0.4

# %% [markdown]
# Assigning both the functions as target to each thread, and calling min support and confidence in args.

# %%
apriorithread = threading.Thread(target=apriori_thread,args=(min_support_ap,min_confidence_ap))
fpthread = threading.Thread(target=fp_thread,args=(min_support_fp,min_confidence_fp))

# %%
apriorithread.start()
fpthread.start()
thread_one.wait()
thread_two.wait()
apriorithread.join()
fpthread.join()

# %%
alg = ['Apriori','Fpgrowth']
plt.bar(alg,execution_time)
plt.xlabel('Algorithm')
plt.ylabel('Execution Time')
plt.title('Apriori and FP growth Performance evaluation')
plt.show()
if execution_time[0]<execution_time[1]:
  print("Apriori is Faster, it has less execution time.")
elif execution_time[1]<execution_time[0]:
  print("FP growth is Faster, it has less execution time.")
# Out:
# FP growth is Faster, it has less execution time.
